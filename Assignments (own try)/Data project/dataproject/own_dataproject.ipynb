# %% [markdown]
# # YOUR PROJECT TITLE

# %% [markdown]
# > **Note the following:**
# > 1. This is *not* meant to be an example of an actual **data analysis project**, just an example of how to structure such a project.
# > 1. Remember the general advice on structuring and commenting your code
# > 1. The `dataproject.py` file includes a function which can be used multiple times in this notebook.

# %% [markdown]
# Download package to make map plots of Denmark:

# %%
#pip install git+https://github.com/sebastianbarfort/mapDK

# %% [markdown]
# Imports and set magics:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from matplotlib_venn import venn2
from dstapi import DstApi


# autoreload modules when code is run
# %load_ext autoreload
# %autoreload 2

# user written modules
import own_dataproject
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Read and clean data

# %% [markdown]
# Import your data, either through an API or manually, and load it.

# %%
kirke = DstApi('KM6')
inc = DstApi('INDKF132')

# %%
tabsum = inc.tablesummary(language='en')
display(tabsum)
# Out:
# Table INDKF132: Disposable family income by region, unit, family type, income interval and time
# Last update: 2022-11-24T08:00:00
#   variable name  # values First value               First value label  \
# 0        OMRÅDE        99         000                     All Denmark
# 1         ENHED         3         102  Families in the group (Number)
# 2        FAMTYP         3        FAIA                 Families, total
# 3      INDKINTB        11          99                           Total
# 4           Tid        35        1987                            1987
#
#   Last value                                Last value label  Time variable
# 0        851                                         Aalborg          False
# 1        117  Average income for families in the group (DKK)          False
# 2       ENIA                            Single people, total          False
# 3        725                         1 million DKK, and more          False
# 4       2021                                            2021           True

# %%
# The available values for a each variable: 
for variable in tabsum['variable name']:
    print(variable+':')
    display(inc.variable_levels(variable, language='en'))
# Out:
# OMRÅDE:
#      id             text
# 0   000      All Denmark
# 1   101       Copenhagen
# 2   147    Frederiksberg
# 3   155           Dragør
# 4   185           Tårnby
# ..  ...              ...
# 94  773            Morsø
# 95  840           Rebild
# 96  787          Thisted
# 97  820  Vesthimmerlands
# 98  851          Aalborg
#
# [99 rows x 2 columns]
# ENHED:
#     id                                            text
# 0  102                  Families in the group (Number)
# 1  110                    Amount of income (DKK 1.000)
# 2  117  Average income for families in the group (DKK)
# FAMTYP:
#      id                  text
# 0  FAIA       Families, total
# 1  PAIA        Couples, total
# 2  ENIA  Single people, total
# INDKINTB:
#      id                     text
# 0    99                    Total
# 1   800    Less than 200,000 DKK
# 2   810    200,000 - 299,999 DKK
# 3   815    300,000 - 399,999 DKK
# 4   820    400,000 - 499,999 DKK
# 5   600    500,000 - 599,999 DKK
# 6   700    600,000 - 699,999 DKK
# 7   710    700,000 - 799,000 DKK
# 8   715    800,000 - 899,000 DKK
# 9   720    900,000 - 999,000 DKK
# 10  725  1 million DKK, and more
# Tid:
#       id  text
# 0   1987  1987
# 1   1988  1988
# 2   1989  1989
# 3   1990  1990
# 4   1991  1991
# 5   1992  1992
# 6   1993  1993
# 7   1994  1994
# 8   1995  1995
# 9   1996  1996
# 10  1997  1997
# 11  1998  1998
# 12  1999  1999
# 13  2000  2000
# 14  2001  2001
# 15  2002  2002
# 16  2003  2003
# 17  2004  2004
# 18  2005  2005
# 19  2006  2006
# 20  2007  2007
# 21  2008  2008
# 22  2009  2009
# 23  2010  2010
# 24  2011  2011
# 25  2012  2012
# 26  2013  2013
# 27  2014  2014
# 28  2015  2015
# 29  2016  2016
# 30  2017  2017
# 31  2018  2018
# 32  2019  2019
# 33  2020  2020
# 34  2021  2021

# %%
params = inc._define_base_params(language='en')
params
# Out:
# {'table': 'indkf132',
#  'format': 'BULK',
#  'lang': 'en',
#  'variables': [{'code': 'OMRÅDE', 'values': ['*']},
#   {'code': 'ENHED', 'values': ['*']},
#   {'code': 'FAMTYP', 'values': ['*']},
#   {'code': 'INDKINTB', 'values': ['*']},
#   {'code': 'Tid', 'values': ['*']}]}

# %%
params = {'table': 'indkf132',
 'format': 'BULK',
 'lang': 'en',
 'variables': [{'code': 'OMRÅDE', 'values': ['*']},
  {'code': 'ENHED', 'values': ['110']},
  {'code': 'FAMTYP', 'values': ['*']},
  {'code': 'INDKINTB', 'values': ['99']},
  {'code': 'Tid', 'values': ['*']}]}

# %%
inc_table = inc.get_data(params=params)
#CHR:use the method get_data and then you feed in the params dictionary that we have created, and then you download the data
inc_table.head(5)
# Out:
#       OMRÅDE                         ENHED                FAMTYP INDKINTB  \
# 0  Rudersdal  Amount of income (DKK 1.000)  Single people, total    Total
# 1  Rudersdal  Amount of income (DKK 1.000)       Families, total    Total
# 2  Rudersdal  Amount of income (DKK 1.000)        Couples, total    Total
# 3     Egedal  Amount of income (DKK 1.000)  Single people, total    Total
# 4     Egedal  Amount of income (DKK 1.000)       Families, total    Total
#
#     TID   INDHOLD
# 0  2018   4556836
# 1  2018  18675308
# 2  2018  14118472
# 3  2018   2101655
# 4  2018   9560281

# %%
inc_table.sort_values(by=['OMRÅDE', 'TID', 'FAMTYP'], inplace=True)
inc_table.head(5)
# Out:
#         OMRÅDE                         ENHED                FAMTYP INDKINTB  \
# 4182  Aabenraa  Amount of income (DKK 1.000)        Couples, total    Total
# 4183  Aabenraa  Amount of income (DKK 1.000)       Families, total    Total
# 4181  Aabenraa  Amount of income (DKK 1.000)  Single people, total    Total
# 6195  Aabenraa  Amount of income (DKK 1.000)        Couples, total    Total
# 6196  Aabenraa  Amount of income (DKK 1.000)       Families, total    Total
#
#        TID  INDHOLD
# 4182  1987  2645508
# 4183  1987  3525080
# 4181  1987   879571
# 6195  1988  2801653
# 6196  1988  3738808

# %%
inc_table_000=inc_table.loc[:, ['OMRÅDE', 'TID', 'FAMTYP','INDHOLD']]

# %%
inc_table_000
# Out:
#         OMRÅDE   TID                FAMTYP  INDHOLD
# 4182  Aabenraa  1987        Couples, total  2645508
# 4183  Aabenraa  1987       Families, total  3525080
# 4181  Aabenraa  1987  Single people, total   879571
# 6195  Aabenraa  1988        Couples, total  2801653
# 6196  Aabenraa  1988       Families, total  3738808
# ...        ...   ...                   ...      ...
# 997        Ærø  2020       Families, total  1139427
# 996        Ærø  2020  Single people, total   438829
# 8663       Ærø  2021        Couples, total   730489
# 8662       Ærø  2021       Families, total  1190369
# 8661       Ærø  2021  Single people, total   459880
#
# [10395 rows x 4 columns]

# %%
inc_grouped=inc_table_000.groupby(['OMRÅDE', 'TID'])['INDHOLD'].apply('sum')

# %%
inc_grouped.info()
# Out:
# <class 'pandas.core.series.Series'>
# MultiIndex: 3465 entries, ('Aabenraa', 1987) to ('Ærø', 2021)
# Series name: INDHOLD
# Non-Null Count  Dtype
# --------------  -----
# 3465 non-null   int64
# dtypes: int64(1)
# memory usage: 166.1+ KB

# %%
I = inc_table_000.FAMTYP.str.contains('Families, total')
inc_table_010 = inc_table_000.loc[I, ['OMRÅDE', 'TID']]

# %%
inc_table_010
# Out:
#         OMRÅDE   TID
# 4183  Aabenraa  1987
# 6196  Aabenraa  1988
# 4669  Aabenraa  1989
# 3464  Aabenraa  1990
# 4003  Aabenraa  1991
# ...        ...   ...
# 2230       Ærø  2017
# 440        Ærø  2018
# 2025       Ærø  2019
# 997        Ærø  2020
# 8662       Ærø  2021
#
# [3465 rows x 2 columns]

# %%
inc_grouped
# Out:
# OMRÅDE    TID
# Aabenraa  1987    7050159
#           1988    7477616
#           1989    7987724
#           1990    8327578
#           1991    8823632
#                    ...
# Ærø       2017    2150522
#           2018    2151716
#           2019    2185986
#           2020    2278854
#           2021    2380738
# Name: INDHOLD, Length: 3465, dtype: int64

# %%
inc_table_020 = inc_table_010.set_index(['OMRÅDE', 'TID']).join(inc_grouped, how='left')
inc_table_020
# Out:
#                INDHOLD
# OMRÅDE   TID
# Aabenraa 1987  7050159
#          1988  7477616
#          1989  7987724
#          1990  8327578
#          1991  8823632
# ...                ...
# Ærø      2017  2150522
#          2018  2151716
#          2019  2185986
#          2020  2278854
#          2021  2380738
#
# [3465 rows x 1 columns]

# %% [markdown]
# ## Explore each data set

# %% [markdown]
# In order to be able to **explore the raw data**, you may provide **static** and **interactive plots** to show important developments

# %% [markdown]
# # Merge data sets

# %% [markdown]
# Now you create combinations of your loaded data sets. Remember the illustration of a (inner) **merge**:

# %%
plt.figure(figsize=(15,7))
v = venn2(subsets = (4, 4, 10), set_labels = ('Data X', 'Data Y'))
v.get_label_by_id('100').set_text('dropped')
v.get_label_by_id('010').set_text('dropped' )
v.get_label_by_id('110').set_text('included')
plt.show()

# %% [markdown]
# Here we are dropping elements from both data set X and data set Y. A left join would keep all observations in data X intact and subset only from Y.
#
# Make sure that your resulting data sets have the correct number of rows and columns. That is, be clear about which observations are thrown away.
#
# **Note:** Don't make Venn diagrams in your own data project. It is just for exposition.

# %% [markdown]
# # Analysis

# %% [markdown]
# To get a quick overview of the data, we show some **summary statistics** on a meaningful aggregation.

# %% [markdown]
# MAKE FURTHER ANALYSIS. EXPLAIN THE CODE BRIEFLY AND SUMMARIZE THE RESULTS.

# %% [markdown]
# # Conclusion

# %% [markdown]
# ADD CONCISE CONLUSION.
